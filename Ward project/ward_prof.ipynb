# %% [markdown]
# # Libraries

# %%
#https://www.datacamp.com/community/tutorials/fuzzy-string-python

import pandas as pd
import pyreadstat
from fuzzywuzzy import fuzz
from matplotlib import pyplot as plt
pd.options.mode.chained_assignment = None

# %% [markdown]
# # Read Data

# %%
londonCodeDF = pd.read_csv("LondonCodes.csv")
wardDataDemoDF = pd.read_table("WardDataDemo.dat")
wardDataEnviroDF = pd.read_csv("WardDataEnvironment.csv")
wardDataHealthDF = pd.read_sas("WardDataHealth.sas7bdat", format='sas7bdat', encoding="latin1")
wardDataSocDF, meta = pyreadstat.read_sav("WardDataSoc.sav")

# %%
FullDF = pd.DataFrame(columns=['Wardcode', 'District', 'Districtcode'])

# %% [markdown]
# ### London Dataset

# %%
londonCodeDF.head()
# Out:
#                District Districtcode
# 0  Barking and Dagenham         00AB
# 1                Barnet         00AC
# 2                Bexley         00AD
# 3                 Brent         00AE
# 4               Bromley         00AF

# %% [markdown]
# ### Merge on ward name

# %%
wardDataDemoDF.head()
# Out:
#                               Wardname   Children  Greaterthan65  nonwhite  \
# 0               Hackney - Queensbridge  17.542063            8.2      44.7
# 1       Hammersmith & Fulham - S&s End  17.915361            8.4      30.6
# 2           Barking & Dagenham - River  26.851598           10.1      38.4
# 3  Tower Hamlets - Bethnal Green North  18.555872            7.0      49.4
# 4                       Merton - Abbey  15.731861            8.5      26.6
#
#    NotBorninUK  NotEnglishspeaking
# 0         38.3                11.8
# 1         39.0                11.8
# 2         30.9                 9.6
# 3         38.7                15.0
# 4         38.3                12.5

# %%
wardDataHealthDF.head()
# Out:
#                                     Wardname  Population2011Census  \
# 0                           Bromley - Darwin                5110.0
# 1    Kensington and Chelsea - Royal Hospital                7252.0
# 2                     Hillingdon - Harefield                7399.0
# 3  Hammersmith and Fulham - Palace Riverside                7483.0
# 4         Kensington and Chelsea - Pembridge                7659.0
#
#    GeneralFertilityRate  Malelifeexpectancy  Femalelifeexpectancy
# 0                  63.8                81.2                  82.4
# 1                  52.3                80.5                  89.6
# 2                  55.8                78.3                  82.3
# 3                  40.0                80.9                  89.0
# 4                  40.4                82.1                  85.7

# %% [markdown]
# ### Merge on wardcode

# %%
wardDataEnviroDF.head()
# Out:
#   Wardcode  Population2011Census  Crimerate  Openspace
# 0   00ANGQ                 11201      117.7        0.0
# 1   00ANGA                 11518      114.0        0.3
# 2   00ADGN                 10800       44.2        0.7
# 3   00BEGH                 12321       65.3        0.7
# 4   00BCFZ                 12609       64.3        1.3

# %%
wardDataSocDF.head()
# Out:
#   Wardcode  hhSocialRented  JobSeekers  Noqual  Carsperhousehold
# 0   00ABFX            26.7         8.7    16.4               0.5
# 1   00ABFY            36.8        10.2    31.2               0.8
# 2   00ABFZ            29.4        10.2    28.0               0.9
# 3   00ABGB            20.0         8.8    29.9               1.1
# 4   00ABGC            37.4        10.2    28.9               0.8

# %% [markdown]
# ### Fuzzy Matching Method

# %%
def get_match(Str1, Str2):
    Ratio = fuzz.ratio(Str1.lower(),Str2.lower())
    return Ratio

def get_P_match(Str1, Str2):
    Partial_Ratio = fuzz.partial_ratio(Str1.lower(),Str2.lower())
    return Partial_Ratio

# %% [markdown]
# ###  Merge the two wardcode tables

# %%
columns = ['Wardcode', 'Population2011Census', 'Crimerate', 'Openspace', 'hhSocialRented', 'JobSeekers', 'Noqual','Carsperhousehold']
FullWardDataDF = pd.DataFrame(columns=columns)
for i in range(0,len(wardDataEnviroDF)):
    for j in range(0,len(wardDataSocDF)):
        if(get_match( wardDataEnviroDF['Wardcode'][i], wardDataSocDF['Wardcode'][j]) > 90):
            FullWardDataDF.loc[len(FullWardDataDF)] = [wardDataEnviroDF['Wardcode'][i], wardDataEnviroDF['Population2011Census'][i],wardDataEnviroDF['Crimerate'][i], wardDataEnviroDF['Openspace'][i],wardDataSocDF['hhSocialRented'][j],wardDataSocDF['JobSeekers'][j],wardDataSocDF['Noqual'][j],wardDataSocDF['Carsperhousehold'][j]]
            #print (str(i)+ " " + str(j))

# %%
FullWardDataDF.head()
# Out:
#   Wardcode Population2011Census  Crimerate  Openspace  hhSocialRented  \
# 0   00ANGQ                11201      117.7        0.0            23.7
# 1   00ANGA                11518      114.0        0.3            24.9
# 2   00ADGN                10800       44.2        0.7             1.1
# 3   00BEGH                12321       65.3        0.7            20.3
# 4   00BCFZ                12609       64.3        1.3             4.7
#
#    JobSeekers  Noqual  Carsperhousehold
# 0         3.6     9.4               0.6
# 1         4.5     9.3               0.5
# 2         2.9    22.1               1.3
# 3         4.6    12.3               0.7
# 4         4.2    17.2               1.2

# %% [markdown]
# ### Merge the two wardname tables

# %%
columns = ['Wardname','Children','Greaterthan65','nonwhite','NotBorninUK','NotEnglishspeaking', 'Population2011Census','GeneralFertilityRate','Malelifeexpectancy','Femalelifeexpectancy']
FullHealthDataDF = pd.DataFrame(columns=columns)

for i in range(0,len(wardDataDemoDF)):
    for j in range(0,len(wardDataHealthDF)):
        if(get_match( str(wardDataDemoDF['Wardname'][i]), str(wardDataHealthDF['Wardname'][j])) > 93):
            FullHealthDataDF.loc[len(FullHealthDataDF)] = [wardDataDemoDF['Wardname'][i], wardDataDemoDF['Children'][i],wardDataDemoDF['Greaterthan65'][i], wardDataDemoDF['nonwhite'][i],wardDataDemoDF['NotBorninUK'][i],wardDataDemoDF['NotEnglishspeaking'][i],wardDataHealthDF['Population2011Census'][j],wardDataHealthDF['GeneralFertilityRate'][j],wardDataHealthDF['Malelifeexpectancy'][j],wardDataHealthDF['Femalelifeexpectancy'][j]]
            break

# %%
FullHealthDataDF.head()
# Out:
#                                 Wardname   Children  Greaterthan65  nonwhite  \
# 0                 Hackney - Queensbridge  17.542063            8.2      44.7
# 1    Tower Hamlets - Bethnal Green North  18.555872            7.0      49.4
# 2                         Merton - Abbey  15.731861            8.5      26.6
# 3  Richmond upon Thames - South Richmond  16.552680           14.0      13.1
# 4                     Lambeth - Larkhall  16.656034            6.2      43.3
#
#    NotBorninUK  NotEnglishspeaking  Population2011Census  \
# 0         38.3                11.8               13670.0
# 1         38.7                15.0               13683.0
# 2         38.3                12.5               10323.0
# 3         33.0                 8.5               10649.0
# 4         42.2                13.0               17243.0
#
#    GeneralFertilityRate  Malelifeexpectancy  Femalelifeexpectancy
# 0                  69.8                75.9                  82.6
# 1                  54.5                73.6                  78.6
# 2                  52.6                80.0                  81.0
# 3                  76.4                83.8                  86.1
# 4                  38.8                74.0                  79.2

# %% [markdown]
# ### Make Final DF

# %%
CompleteDF = pd.DataFrame(columns=['Ward_Name','District','Districtcode'])

for i in range(0,len(FullHealthDataDF)):
    for j in range(0,len(londonCodeDF)):
        if(get_P_match( str(FullHealthDataDF['Wardname'][i]), str(londonCodeDF['District'][j])) > 90):
            CompleteDF.loc[len(CompleteDF)] = [FullHealthDataDF['Wardname'][i], londonCodeDF['District'][j],londonCodeDF['Districtcode'][j]]
            break

# %%
CompleteDF.head()
# Out:
#                                    Ward_Name              District  \
# 0                     Hackney - Queensbridge               Hackney
# 1        Tower Hamlets - Bethnal Green North         Tower Hamlets
# 2                             Merton - Abbey                Merton
# 3      Richmond upon Thames - South Richmond  Richmond upon Thames
# 4                         Lambeth - Larkhall               Lambeth
# 5                      Greenwich - Plumstead             Greenwich
# 6             Hillingdon - Heathrow Villages            Hillingdon
# 7                   Lambeth - Streatham Hill               Lambeth
# 8                        Havering - Gooshays              Havering
# 9                      Croydon - Broad Green               Croydon
# 10                 Hillingdon - West Ruislip            Hillingdon
# 11                  Ealing - North Greenford                Ealing
# 12               Lewisham - Lewisham Central              Lewisham
# 13              Hillingdon - Hillingdon East            Hillingdon
# 14                  Wandsworth - Southfields            Wandsworth
# 15                    Hounslow - Heston West              Hounslow
# 16                      Sutton - Sutton West                Sutton
# 17                        Merton - Dundonald                Merton
# 18                     Haringey - West Green              Haringey
# 19                 Hounslow - Heston Central              Hounslow
# 20                        Barnet - Underhill                Barnet
# 21                   Sutton - Sutton Central                Sutton
# 22                     Bexley - Lesnes Abbey                Bexley
# 23                Southwark - Brunswick Park             Southwark
# 24                  Redbridge - Clementswood             Redbridge
# 25                     Islington - Barnsbury             Islington
# 26                         Croydon - Shirley               Croydon
# 27                    Wandsworth - Northcote            Wandsworth
# 28               Greenwich - Woolwich Common             Greenwich
# 29                     Croydon - Sanderstead               Croydon
# ..                                       ...                   ...
# 514                 Tower Hamlets - Shadwell         Tower Hamlets
# 515                        Croydon - Norbury               Croydon
# 516             Waltham Forest - Higham Hill        Waltham Forest
# 517                        Brent - Tokyngton                 Brent
# 518                    Haringey - Crouch End              Haringey
# 519                      Hackney - New River               Hackney
# 520  Tower Hamlets - Blackwall & Cubitt Town         Tower Hamlets
# 521                     Bromley - Shortlands               Bromley
# 522                  Westminster - Tachbrook           Westminster
# 523                   Barnet - East Finchley                Barnet
# 524                   Merton - Colliers Wood                Merton
# 525                  Havering - Emerson Park              Havering
# 526                  Havering - Romford Town              Havering
# 527                     Harrow - Kenton West                Harrow
# 528        Kingston upon Thames - Berrylands  Kingston upon Thames
# 529                  Camden - West Hampstead                Camden
# 530                 Hounslow - Hounslow West              Hounslow
# 531                      Lewisham - Ladywell              Lewisham
# 532                 Greenwich - Eltham North             Greenwich
# 533                Hounslow - Hounslow Heath              Hounslow
# 534                 Hounslow - Feltham North              Hounslow
# 535                       Redbridge - Bridge             Redbridge
# 536                     Haringey - Noel Park              Haringey
# 537       Kingston upon Thames - Coombe Vale  Kingston upon Thames
# 538                    Bromley - Chislehurst               Bromley
# 539                     Haringey - Harringay              Haringey
# 540                    Lambeth - Coldharbour               Lambeth
# 541                  Newham - Plaistow North                Newham
# 542                   Greenwich - Abbey Wood             Greenwich
# 543             Southwark - South Camberwell             Southwark
#
#     Districtcode
# 0           00AM
# 1           00BG
# 2           00BA
# 3           00BD
# 4           00AY
# 5           00AL
# 6           00AS
# 7           00AY
# 8           00AR
# 9           00AH
# 10          00AS
# 11          00AJ
# 12          00AZ
# 13          00AS
# 14          00BJ
# 15          00AT
# 16          00BF
# 17          00BA
# 18          00AP
# 19          00AT
# 20          00AC
# 21          00BF
# 22          00AD
# 23          00BE
# 24          00BC
# 25          00AU
# 26          00AH
# 27          00BJ
# 28          00AL
# 29          00AH
# ..           ...
# 514         00BG
# 515         00AH
# 516         00BH
# 517         00AE
# 518         00AP
# 519         00AM
# 520         00BG
# 521         00AF
# 522         00BK
# 523         00AC
# 524         00BA
# 525         00AR
# 526         00AR
# 527         00AQ
# 528         00AX
# 529         00AG
# 530         00AT
# 531         00AZ
# 532         00AL
# 533         00AT
# 534         00AT
# 535         00BC
# 536         00AP
# 537         00AX
# 538         00AF
# 539         00AP
# 540         00AY
# 541         00BB
# 542         00AL
# 543         00BE
#
# [544 rows x 3 columns]

# %%
FullWardDataDF.head()
# Out:
#   Wardcode Population2011Census  Crimerate  Openspace  hhSocialRented  \
# 0   00ANGQ                11201      117.7        0.0            23.7
# 1   00ANGA                11518      114.0        0.3            24.9
# 2   00ADGN                10800       44.2        0.7             1.1
# 3   00BEGH                12321       65.3        0.7            20.3
# 4   00BCFZ                12609       64.3        1.3             4.7
#
#    JobSeekers  Noqual  Carsperhousehold
# 0         3.6     9.4               0.6
# 1         4.5     9.3               0.5
# 2         2.9    22.1               1.3
# 3         4.6    12.3               0.7
# 4         4.2    17.2               1.2

# %%
CompleteDF['Population2011Census'] = None
CompleteDF['Crimerate'] = None
CompleteDF['Openspace'] = None
CompleteDF['hhSocialRented'] = None
CompleteDF['JobSeekers'] = None
CompleteDF['Noqual'] = None
CompleteDF['Carsperhousehold'] = None

for i in range(0,len(FullWardDataDF)):
    for j in range(0,len(CompleteDF)):
        if(get_match( str(FullWardDataDF['Wardcode'][i][:-2]), str(CompleteDF['Districtcode'][j]).strip()) > 90):
            CompleteDF.loc[j,'Population2011Census'] = FullWardDataDF['Population2011Census'][i]
            CompleteDF.loc[j,'Crimerate'] = FullWardDataDF['Crimerate'][i]
            CompleteDF.loc[j,'Openspace'] = FullWardDataDF['Openspace'][i]
            CompleteDF.loc[j,'hhSocialRented'] = FullWardDataDF['hhSocialRented'][i]
            CompleteDF.loc[j,'JobSeekers'] = FullWardDataDF['JobSeekers'][i]
            CompleteDF.loc[j,'Noqual'] = FullWardDataDF['Noqual'][i]
            CompleteDF.loc[j,'Carsperhousehold'] = FullWardDataDF['Carsperhousehold'][i]

# %%
CompleteDF.rename(columns={'Ward_Name': 'Wardname'}, inplace=True)
CompleteDF = pd.merge(CompleteDF, FullHealthDataDF, on='Wardname')

# %%
# Calculate Joint Life expectancy
def newlife(row):
    return (row['Malelifeexpectancy'] + row['Femalelifeexpectancy'])/2

# %%
CompleteDF['LifeTotal'] = CompleteDF.apply(newlife, axis=1)

# %%
CompleteDF
# Out:
#                                     Wardname              District  \
# 0                     Hackney - Queensbridge               Hackney
# 1        Tower Hamlets - Bethnal Green North         Tower Hamlets
# 2                             Merton - Abbey                Merton
# 3      Richmond upon Thames - South Richmond  Richmond upon Thames
# 4                         Lambeth - Larkhall               Lambeth
# 5                      Greenwich - Plumstead             Greenwich
# 6             Hillingdon - Heathrow Villages            Hillingdon
# 7                   Lambeth - Streatham Hill               Lambeth
# 8                        Havering - Gooshays              Havering
# 9                      Croydon - Broad Green               Croydon
# 10                 Hillingdon - West Ruislip            Hillingdon
# 11                  Ealing - North Greenford                Ealing
# 12               Lewisham - Lewisham Central              Lewisham
# 13              Hillingdon - Hillingdon East            Hillingdon
# 14                  Wandsworth - Southfields            Wandsworth
# 15                    Hounslow - Heston West              Hounslow
# 16                      Sutton - Sutton West                Sutton
# 17                        Merton - Dundonald                Merton
# 18                     Haringey - West Green              Haringey
# 19                 Hounslow - Heston Central              Hounslow
# 20                        Barnet - Underhill                Barnet
# 21                   Sutton - Sutton Central                Sutton
# 22                     Bexley - Lesnes Abbey                Bexley
# 23                Southwark - Brunswick Park             Southwark
# 24                  Redbridge - Clementswood             Redbridge
# 25                     Islington - Barnsbury             Islington
# 26                         Croydon - Shirley               Croydon
# 27                    Wandsworth - Northcote            Wandsworth
# 28               Greenwich - Woolwich Common             Greenwich
# 29                     Croydon - Sanderstead               Croydon
# ..                                       ...                   ...
# 514                 Tower Hamlets - Shadwell         Tower Hamlets
# 515                        Croydon - Norbury               Croydon
# 516             Waltham Forest - Higham Hill        Waltham Forest
# 517                        Brent - Tokyngton                 Brent
# 518                    Haringey - Crouch End              Haringey
# 519                      Hackney - New River               Hackney
# 520  Tower Hamlets - Blackwall & Cubitt Town         Tower Hamlets
# 521                     Bromley - Shortlands               Bromley
# 522                  Westminster - Tachbrook           Westminster
# 523                   Barnet - East Finchley                Barnet
# 524                   Merton - Colliers Wood                Merton
# 525                  Havering - Emerson Park              Havering
# 526                  Havering - Romford Town              Havering
# 527                     Harrow - Kenton West                Harrow
# 528        Kingston upon Thames - Berrylands  Kingston upon Thames
# 529                  Camden - West Hampstead                Camden
# 539                  64.0                78.4                  81.8      80.10
# 540                  63.0                73.1                  80.0      76.55
# 541                  96.0                75.3                  82.2      78.75
# 542                 105.3                74.3                  81.1      77.70
# 543                  56.9                76.4                  84.6      80.50
#
# [544 rows x 20 columns]

# %% [markdown]
# ## Make DF for model

# %%
new_columns = ['Wardname', 'Population2011Census_x', 'Openspace', 'Carsperhousehold', 'Children', 'Greaterthan65', 'nonwhite', 'NotBorninUK', 'NotEnglishspeaking', 'GeneralFertilityRate','JobSeekers','Noqual', 'Crimerate', 'hhSocialRented',  'LifeTotal']
latest_DF = CompleteDF[new_columns]

# %%
latest_DF.head(1)
# Out:
#                  Wardname Population2011Census_x Openspace Carsperhousehold  \
# 0  Hackney - Queensbridge                  11098      67.7              0.5
#
#     Children  Greaterthan65  nonwhite  NotBorninUK  NotEnglishspeaking  \
# 0  17.542063            8.2      44.7         38.3                11.8
#
#    GeneralFertilityRate JobSeekers Noqual Crimerate hhSocialRented  LifeTotal
# 0                  69.8       13.6   24.6      61.9           57.9      79.25

# %% [markdown]
# ## Make Model

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import label
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Label Encode the wards
labelEncoder = label.LabelEncoder()
latest_DF['Wardname'] = labelEncoder.fit_transform(latest_DF.Wardname)

# %%
latest_DF.head(1)
# Out:
#    Wardname Population2011Census_x Openspace Carsperhousehold   Children  \
# 0       190                  11098      67.7              0.5  17.542063
#
#    Greaterthan65  nonwhite  NotBorninUK  NotEnglishspeaking  \
# 0            8.2      44.7         38.3                11.8
#
#    GeneralFertilityRate JobSeekers Noqual Crimerate hhSocialRented  LifeTotal
# 0                  69.8       13.6   24.6      61.9           57.9      79.25

# %%
# Use min max scaler
scaler = MinMaxScaler()
latest_DF_Scaled = scaler.fit_transform(latest_DF)
latest_DF_Scaled = pd.DataFrame(data=latest_DF_Scaled, columns=latest_DF.columns)

# %%
latest_DF_Scaled.head()
# Out:
#    Wardname  Population2011Census_x  Openspace  Carsperhousehold  Children  \
# 0  0.349908                0.448842   0.588761          0.000000  0.399489
# 1  0.867403                0.586838   0.273308          0.000000  0.438401
# 2  0.659300                0.253429   0.518519          0.750000  0.330011
# 3  0.788214                0.390301   0.770115          0.416667  0.361515
# 4  0.607735                0.749344   0.208174          0.000000  0.365482
#
#    Greaterthan65  nonwhite  NotBorninUK  NotEnglishspeaking  \
# 0          0.235  0.453125     0.523659            0.114804
# 1          0.175  0.505580     0.529968            0.147029
# 2          0.250  0.251116     0.523659            0.121853
# 3          0.525  0.100446     0.440063            0.081571
# 4          0.135  0.437500     0.585174            0.126888
#
#    GeneralFertilityRate  JobSeekers    Noqual  Crimerate  hhSocialRented  \
# 0              0.449576    0.423077  0.974227   0.167794        1.000000
# 1              0.305372    0.269231  0.752577   0.732070        0.662500
# 2              0.287465    0.016026  0.056701   0.156969        0.066071
# 3              0.511781    0.086538  0.432990   0.194181        0.296429
# 4              0.157399    0.259615  0.335052   0.652909        0.533929
#
#    LifeTotal       IMD  _intercept
# 0   0.092377  0.593028           1
# 1   0.035874  0.475678           1
# 2   0.114798  0.045293           1
# 3   0.194619  0.204905           1
# 4   0.044843  0.345235           1

# %% [markdown]
# ### Calc IMD

# %%
def imd(row):
    return((row['JobSeekers']*0.55)+(row['Noqual']*0.25)+(row['Crimerate']*0.10)+(row['hhSocialRented']*0.10))

# %%
latest_DF_Scaled['IMD'] = latest_DF_Scaled.apply(imd, axis=1)

# %% [markdown]
# ## Make X and Y datasets

# %%
y = latest_DF_Scaled['LifeTotal']
latest_DF_Scaled = latest_DF_Scaled.drop(columns=['JobSeekers', 'Noqual', 'Crimerate', 'hhSocialRented', 'LifeTotal'], axis=1)
x = latest_DF_Scaled

# %%
x.head()
# Out:
#    Wardname  Population2011Census_x  Openspace  Carsperhousehold  Children  \
# 0  0.349908                0.448842   0.588761          0.000000  0.399489
# 1  0.867403                0.586838   0.273308          0.000000  0.438401
# 2  0.659300                0.253429   0.518519          0.750000  0.330011
# 3  0.788214                0.390301   0.770115          0.416667  0.361515
# 4  0.607735                0.749344   0.208174          0.000000  0.365482
#
#    Greaterthan65  nonwhite  NotBorninUK  NotEnglishspeaking  \
# 0          0.235  0.453125     0.523659            0.114804
# 1          0.175  0.505580     0.529968            0.147029
# 2          0.250  0.251116     0.523659            0.121853
# 3          0.525  0.100446     0.440063            0.081571
# 4          0.135  0.437500     0.585174            0.126888
#
#    GeneralFertilityRate       IMD  _intercept
# 0              0.449576  0.593028           1
# 1              0.305372  0.475678           1
# 2              0.287465  0.045293           1
# 3              0.511781  0.204905           1
# 4              0.157399  0.345235           1

# %%
#Reference Variable
latest_DF_Scaled['_intercept'] = 1

# %% [markdown]
# # Train Model

# %%
import statsmodels.api as sm
import numpy as np
# split the dataset into the training set and test set
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size= 0.3, random_state=0)
    
logit = sm.OLS(np.array(y_train), np.array(X_train))
    
    # Fit the model
result = logit.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.239
# Method:                 Least Squares   F-statistic:                     11.81
# Date:                Fri, 12 Apr 2019   Prob (F-statistic):           5.48e-19
# Time:                        15:21:25   Log-Likelihood:                 659.30
# No. Observations:                 380   AIC:                            -1295.
# Df Residuals:                     368   BIC:                            -1247.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0126      0.009      1.400      0.162      -0.005       0.030
# x2            -0.0036      0.012     -0.289      0.773      -0.028       0.021
# x3             0.0030      0.013      0.227      0.820      -0.023       0.029
# x4             0.0355      0.013      2.781      0.006       0.010       0.061
# x5             0.0049      0.029      0.169      0.866      -0.052       0.062
# x6             0.0895      0.017      5.149      0.000       0.055       0.124
# x7            -0.1116      0.024     -4.728      0.000      -0.158      -0.065
# x8             0.1484      0.045      3.272      0.001       0.059       0.238
# x9             0.0243      0.102      0.239      0.811      -0.176       0.224
# x10           -0.0123      0.020     -0.603      0.547      -0.052       0.028
# x11            0.0079      0.022      0.361      0.718      -0.035       0.051
# const          0.0381      0.024      1.593      0.112      -0.009       0.085
# ==============================================================================
# Omnibus:                       48.931   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              128.837
# Skew:                           0.616   Prob(JB):                     1.06e-28
# Kurtosis:                       5.572   Cond. No.                         87.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
