# %%
# Libraries
import pandas as pd
import numpy  as np
from matplotlib import pyplot as plt
import datetime as dt

# %% [markdown]
# ## 1) Reviewing data, initial analysis

# %%
plt.figure(figsize=(50, 50), dpi= 100, facecolor='w', edgecolor='k')

# %%
feature_df = pd.read_csv("features.csv")
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")
store_df = pd.read_csv("stores.csv")

# %%
feature_df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0      1  05/02/2010        42.31       2.572         NaN         NaN
# 1      1  12/02/2010        38.51       2.548         NaN         NaN
# 2      1  19/02/2010        39.93       2.514         NaN         NaN
# 3      1  26/02/2010        46.63       2.561         NaN         NaN
# 4      1  05/03/2010        46.50       2.625         NaN         NaN
#
#    Promotion3  Promotion4  Promotion5         CPI  Unemployment  IsHoliday
# 0         NaN         NaN         NaN  211.096358         8.106      False
# 1         NaN         NaN         NaN  211.242170         8.106       True
# 2         NaN         NaN         NaN  211.289143         8.106      False
# 3         NaN         NaN         NaN  211.319643         8.106      False
# 4         NaN         NaN         NaN  211.350143         8.106      False

# %%
feature_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
# Store           8190 non-null int64
# Date            8190 non-null object
# Temperature     8190 non-null float64
# Fuel_Price      8190 non-null float64
# Promotion1      4032 non-null float64
# Promotion2      2921 non-null float64
# Promotion3      3613 non-null float64
# Promotion4      3464 non-null float64
# Promotion5      4050 non-null float64
# CPI             7605 non-null float64
# Unemployment    7605 non-null float64
# IsHoliday       8190 non-null bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 711.9+ KB

# %%
train_df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
# Store           421570 non-null int64
# Dept            421570 non-null int64
# Date            421570 non-null object
# Weekly_Sales    421570 non-null float64
# IsHoliday       421570 non-null bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
test_df.head()
# Out:
#    Store  Dept        Date  IsHoliday  Weekly_Sales to be predicted
# 0      1     1  02/11/2012      False                           NaN
# 1      1     1  09/11/2012      False                           NaN
# 2      1     1  16/11/2012      False                           NaN
# 3      1     1  23/11/2012       True                           NaN
# 4      1     1  30/11/2012      False                           NaN

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115064 entries, 0 to 115063
# Data columns (total 5 columns):
# Store                           115064 non-null int64
# Dept                            115064 non-null int64
# Date                            115064 non-null object
# IsHoliday                       115064 non-null bool
# Weekly_Sales to be predicted    0 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 3.6+ MB

# %%
store_df.head()
# Out:
#    Store Type  Size (sq ft)
# 0      1    A        151315
# 1      2    A        202307
# 2      3    B         37392
# 3      4    A        205863
# 4      5    B         34875

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
# Store           45 non-null int64
# Type            45 non-null object
# Size (sq ft)    45 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 1.1+ KB

# %% [markdown]
# ### We first need to analyse the datatypes for each variable stored in the tables (columns).
#
#
# Feature_df (8189 rows)
# - Date: needs to be converted into a datetime dtype as we can't use it currently in any graph as a type error would be thrown.
# - IsHoliday: is a categorical dtype, we can definitely use it to categorise data and compare relations between holidays and non-holidays.
#
#
# Train_df (421569 rows)
# - Date: needs to be converted into datetime dtype for reasons mentiond above.
#
#
# Test_df (115063 rows)
# - Date: needs to be converted into datetime dtype for reasons mentiond above.

# %%
# Check if Null values exist
def null_checker(dataframe_column):
    return dataframe_column.isnull().sum().sum()

# %% [markdown]
# # Some initial exploratory analysis of the data before we merge the tables.

# %%
# %matplotlib inline
feature_df.plot.scatter(x = "CPI", y = "Fuel_Price", color = 'DarkGreen', figsize=(18, 16))

# %%
feature_df.plot.scatter(x = "Store", y = "Promotion1", color = 'DarkGreen', figsize=(18, 16))

# %%
feature_df.plot.scatter(x = "Store", y = "Promotion2", color = 'DarkGreen', figsize=(18, 16))

# %%
feature_df.plot.scatter(x = "Store", y = "Promotion5", color = 'DarkGreen', figsize=(18, 16))

# %% [markdown]
# ## The scatter plots don't  inform us clearly about missing  data, however, we can clearly identify some outliers in some  of  the graphs. For `promotions 1` and  `2` we can see very similar trends where stores have more low value promotions and less high value promotions. For `promotion 5` we can clearly see a common trend of very low values of promotion across all 45 stores but one promotion value between `700000` and `800000`.

# %% [markdown]
# # Using the null_checker function we wrote above, we can now tabulate the variables with missing values for all tables to get a better picture of missing data and its potential impact:
#
#
# |                 | Stores | Features | Test   | Train |
# |-----------------|--------|----------|--------|-------|
# | Store           | 0      | 0        | 0      | 0     |
# | Type            | 0      |          |        |       |
# | Size            | 0      |          |        |       |
# | Date            |        | 0        | 0      | 0     |
# | Temp            |        | 0        |        |       |
# | Fuel_P          |        | 0        |        |       |
# | Promotion1      |        | 4158     |        |       |
# | Promotion2      |        | 5269     |        |       |
# | Promotion3      |        | 4577     |        |       |
# | Promotion4      |        | 4726     |        |       |
# | Promotion5      |        | 4140     |        |       |
# | CPI             |        | 585      |        |       |
# | Unemployment    |        | 585      |        |       |
# | IsHoliday       |        | 0        | 0      | 0     |
# | Department      |        |          | 0      | 0     |
# | Weekly_Sales    |        |          |        | 0     |
# | Weekly_Salestbp |        |          | 115064 |       |

# %% [markdown]
# ## We can see after running the function null_checker that the number of empty rows for promotions 1..5 vary. The promotion with the most values filled is `Promotion 5`

# %%
feature_df.Promotion1
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
#           ...
# 8160     1341.33
# 8161     3877.36
# 8162    14746.10
# 8163     3130.28
# 8164    14508.96
# 8165    53311.88
# 8166     9362.02
# 8167    10781.51
# 8168     6614.32
# 8169    16382.54
# 8170     9867.03
# 8171    11923.74
# 8172     5444.00
# 8173    16427.83
# 8174     8760.15
# 8175     1399.81
# 8176     1260.65
# 8177     8345.40
# 8178     4689.18
# 8179     4515.35
# 8180     3249.34
# 8181     6474.49
# 8182     9977.82
# 8183     2471.44
# 8184     4989.34
# 8185     4842.29
# 8186     9090.48
# 8187     3789.94
# 8188     2961.49
# 8189      212.02
# Name: Promotion1, Length: 8190, dtype: float64

# %% [markdown]
# Regarding quality of the datasets. The values stored is mainly floating point but what does that indicate specifically? Is it a percentage of promotion? An example of data for `Promotion1` is `53311.88`. Clearly it's price reductions still the values are not very informative. We have some categorical data which would be very useful i.e. `IsHoliday` to try filter the data focusing on holiday promotions and non-holiday promotions. Weekly sales to be predicted is all `Null` but the number of rows can give us a picture of the amount of data we have to produce which is: 115064. We definitely will be using  `Weekly_Sales` with `Promotions` and `IsHolidays` with `Dates` to try predict the Sales Forecasting on the `Department` level. The data quality is ok I guess as many key variables required to predict the `Sales forecasts` are provided like `Department`, `IsHoliday`, `WeeklySales`, `Date` and so on. The main problem is we don't have all the data for `Promotions` this too is a key variable and  without it, we can't make accurate predictions of weekly sales. At least, however, we have some data thus we can try predict the missing data using methods like time series analysis.

# %% [markdown]
# # Let us now merge the `features`, `train` and `store` tables

# %% [markdown]
# ### First we will convert the `Date` columns to `DateTime` dtypes

# %%
feature_df['Date'] =  pd.to_datetime(feature_df['Date'],
                              format='%d/%m/%Y')

# %%
train_df['Date'] = pd.to_datetime(train_df['Date'], format='%d/%m/%Y')

# %%
test_df['Date'] = pd.to_datetime(test_df['Date'], format = '%d/%m/%Y')

# %%
# Merging tables store_df
store_feature_merged_df = pd.merge(feature_df, store_df, on='Store')

# %%
store_feature_merged_df.head()
# Out:
#    Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0      1 2010-02-05        42.31       2.572         NaN         NaN
# 1      1 2010-02-12        38.51       2.548         NaN         NaN
# 2      1 2010-02-19        39.93       2.514         NaN         NaN
# 3      1 2010-02-26        46.63       2.561         NaN         NaN
# 4      1 2010-03-05        46.50       2.625         NaN         NaN
#
#    Promotion3  Promotion4  Promotion5         CPI  Unemployment  IsHoliday  \
# 0         NaN         NaN         NaN  211.096358         8.106      False
# 1         NaN         NaN         NaN  211.242170         8.106       True
# 2         NaN         NaN         NaN  211.289143         8.106      False
# 3         NaN         NaN         NaN  211.319643         8.106      False
# 4         NaN         NaN         NaN  211.350143         8.106      False
#
#   Type  Size (sq ft)
# 0    A        151315
# 1    A        151315
# 2    A        151315
# 3    A        151315
# 4    A        151315

# %%
store_feature_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 8189
# Data columns (total 14 columns):
# Store           8190 non-null int64
# Date            8190 non-null datetime64[ns]
# Temperature     8190 non-null float64
# Fuel_Price      8190 non-null float64
# Promotion1      4032 non-null float64
# Promotion2      2921 non-null float64
# Promotion3      3613 non-null float64
# Promotion4      3464 non-null float64
# Promotion5      4050 non-null float64
# CPI             7605 non-null float64
# Unemployment    7605 non-null float64
# IsHoliday       8190 non-null bool
# Type            8190 non-null object
# Size (sq ft)    8190 non-null int64
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(2), object(1)
# memory usage: 903.8+ KB

# %%
# Merging tables store_feature_merged_df with train_df
final_df = pd.merge(train_df, store_feature_merged_df)

# %%
final_df.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50      False        42.31       2.572
# 1      1     2 2010-02-05      50605.27      False        42.31       2.572
# 2      1     3 2010-02-05      13740.12      False        42.31       2.572
# 3      1     4 2010-02-05      39954.04      False        42.31       2.572
# 4      1     5 2010-02-05      32229.38      False        42.31       2.572
#
#    Promotion1  Promotion2  Promotion3  Promotion4  Promotion5         CPI  \
# 0         NaN         NaN         NaN         NaN         NaN  211.096358
# 1         NaN         NaN         NaN         NaN         NaN  211.096358
# 2         NaN         NaN         NaN         NaN         NaN  211.096358
# 3         NaN         NaN         NaN         NaN         NaN  211.096358
# 4         NaN         NaN         NaN         NaN         NaN  211.096358
#
#    Unemployment Type  Size (sq ft)
# 0         8.106    A        151315
# 1         8.106    A        151315
# 2         8.106    A        151315
# 3         8.106    A        151315
# 4         8.106    A        151315

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
# Store           421570 non-null int64
# Dept            421570 non-null int64
# Date            421570 non-null datetime64[ns]
# Weekly_Sales    421570 non-null float64
# IsHoliday       421570 non-null bool
# Temperature     421570 non-null float64
# Fuel_Price      421570 non-null float64
# Promotion1      150681 non-null float64
# Promotion2      111248 non-null float64
# Promotion3      137091 non-null float64
# Promotion4      134967 non-null float64
# Promotion5      151432 non-null float64
# CPI             421570 non-null float64
# Unemployment    421570 non-null float64
# Type            421570 non-null object
# Size (sq ft)    421570 non-null int64
# dtypes: bool(1), datetime64[ns](1), float64(10), int64(3), object(1)
# memory usage: 51.9+ MB

# %%
final_df['Date'].min()
# Out:
# Timestamp('2010-02-05 00:00:00')

# %%
final_df['Date'].max()
# Out:
# Timestamp('2012-10-26 00:00:00')

# %% [markdown]
# ## We successfully merged tables `Store`, `Features` and `Train` after converting `Date` to `DateTime` we can get the `minimum` and `maximum` dates. The minimum date is `2010-02-05` and the maximum date is `2012-10-26`. I now want to try categorise the data based on year and see which years have the most promotional data.

# %%
feature_test_df = pd.merge(feature_df, test_df, on = 'Store')

# %%
train_df = train_df.drop(axis = 1, columns = ['IsHoliday'])

# %%
feature_test_df_v1 = pd.merge(feature_test_df, train_df, on = "Store")

# %%
feature_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20941648 entries, 0 to 20941647
# Data columns (total 16 columns):
# Store                           int64
# Date_x                          datetime64[ns]
# Temperature                     float64
# Fuel_Price                      float64
# Promotion1                      float64
# Promotion2                      float64
# Promotion3                      float64
# Promotion4                      float64
# Promotion5                      float64
# CPI                             float64
# Unemployment                    float64
# IsHoliday_x                     bool
# Dept                            int64
# Date_y                          datetime64[ns]
# IsHoliday_y                     bool
# Weekly_Sales to be predicted    float64
# dtypes: bool(2), datetime64[ns](2), float64(10), int64(2)
# memory usage: 2.4 GB

# %%
feature_test_df.head()
# Out:
#    Store     Date_x  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0      1 2010-02-05        42.31       2.572         NaN         NaN
# 1      1 2010-02-05        42.31       2.572         NaN         NaN
# 2      1 2010-02-05        42.31       2.572         NaN         NaN
# 3      1 2010-02-05        42.31       2.572         NaN         NaN
# 4      1 2010-02-05        42.31       2.572         NaN         NaN
#
#    Promotion3  Promotion4  Promotion5         CPI  Unemployment  IsHoliday_x  \
# 0         NaN         NaN         NaN  211.096358         8.106        False
# 1         NaN         NaN         NaN  211.096358         8.106        False
# 2         NaN         NaN         NaN  211.096358         8.106        False
# 3         NaN         NaN         NaN  211.096358         8.106        False
# 4         NaN         NaN         NaN  211.096358         8.106        False
#
#    Dept     Date_y  IsHoliday_y  Weekly_Sales to be predicted
# 0     1 2012-11-02        False                           NaN
# 1     1 2012-11-09        False                           NaN
# 2     1 2012-11-16        False                           NaN
# 3     1 2012-11-23         True                           NaN
# 4     1 2012-11-30        False                           NaN

# %% [markdown]
# ## When we combine the `feature_df` with the `test_df` we can see that the `promotions` are available for the year `2013` which is stored in the `Date_x` column. We need to try extract that information and use it to perform time series analysis.
#
# ### We now have two sets of tables, these are:
# - Final_df: `train`, `store` and `feature` merged into one
# - feature_test_df: `feature` and `test` combined to get the promotions for 2013.

# %% [markdown]
# ## Now lets get the data for year 2013 from `feature_test_df`

# %%
def get_specific_year_data(dataframe, year):
    return dataframe[dataframe['Date_x'].dt.year == year]

# %%
data_from_2013 = get_specific_year_data(feature_test_df, 2013)

# %% [markdown]
# ## Let's drop the columns `Date_y` and `isHoliday_y` as we don't need these to get the promotions for 2013.

# %%
data_from_2013 = data_from_2013.drop(['Date_y'], axis=1)

# %%
data_from_2013 = data_from_2013.drop(['IsHoliday_y'], axis=1)

# %%
data_from_2013 = data_from_2013.drop(['Dept'], axis=1)

# %%
data_from_2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3451920 entries, 423016 to 20941647
# Data columns (total 13 columns):
# Store                           int64
# Date_x                          datetime64[ns]
# Temperature                     float64
# Fuel_Price                      float64
# Promotion1                      float64
# Promotion2                      float64
# Promotion3                      float64
# Promotion4                      float64
# Promotion5                      float64
# CPI                             float64
# Unemployment                    float64
# IsHoliday_x                     bool
# Weekly_Sales to be predicted    float64
# dtypes: bool(1), datetime64[ns](1), float64(10), int64(1)
# memory usage: 345.7 MB

# %% [markdown]
# ## Date_y and IsHoliday_y has been dropped, now we can focus on the duplicates.

# %% [markdown]
# ## We have all the data for 2013, now we need to get rid of duplicates as we merged both tables.

# %%
data_from_2013_v1 = data_from_2013.drop_duplicates()

# %%
data_from_2013_v1
# Out:
#           Store     Date_x  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 423016        1 2013-01-04        41.73       3.161     1214.08    25366.33
# 425799        1 2013-01-11        50.32       3.243     6520.24    16134.60
# 428582        1 2013-01-18        42.92       3.237     3772.69     3559.46
# 431365        1 2013-01-25        53.37       3.227      965.89     1097.91
# 434148        1 2013-02-01        56.46       3.244     9290.91     1359.90
# 436931        1 2013-02-08        56.67       3.417    32355.16      729.80
# 439714        1 2013-02-15        49.66       3.475    72937.29     6665.52
# 442497        1 2013-02-22        50.25       3.597    20107.75     3163.89
# 445280        1 2013-03-01        48.01       3.711    10610.74      261.46
# 448063        1 2013-03-08        50.81       3.658     5000.58      290.46
# 450846        1 2013-03-15        55.33       3.622     3808.13         NaN
# 453629        1 2013-03-22        63.42       3.611    12553.98         NaN
# 456412        1 2013-03-29        51.00       3.606    13067.46         NaN
# 459195        1 2013-04-05        58.59       3.583    12872.34     5687.86
# 461978        1 2013-04-12        62.72       3.529     3672.43      932.58
# 464761        1 2013-04-19        67.10       3.451     3530.36        3.95
# 467544        1 2013-04-26        59.23       3.417     2387.72         NaN
# 470327        1 2013-05-03        66.66       3.386     2298.63        2.00
# 473110        1 2013-05-10        63.90       3.392     4624.61       83.88
# 475893        1 2013-05-17        69.53       3.454    16170.50       92.00
# 478676        1 2013-05-24        77.19       3.494     7959.89      178.00
# 481459        1 2013-05-31        78.02       3.466     2369.77      142.45
# 484242        1 2013-06-07        76.44       3.439     3514.75      742.59
# 487025        1 2013-06-14        79.86       3.431    12592.32      527.48
# 489808        1 2013-06-21        81.35       3.479     8104.02      417.99
# 492591        1 2013-06-28        83.94       3.495     4205.98      796.70
# 495374        1 2013-07-05        79.85       3.422     7649.99     3503.29
# 448063          False                           NaN
# 450846          False                           NaN
# 453629          False                           NaN
# 456412          False                           NaN
# 459195          False                           NaN
# 461978          False                           NaN
# 464761          False                           NaN
# 467544          False                           NaN
# 470327          False                           NaN
# 473110          False                           NaN
# 475893          False                           NaN
# 478676          False                           NaN
# 481459          False                           NaN
# 484242          False                           NaN
# 487025          False                           NaN
# 489808          False                           NaN
# 492591          False                           NaN
# 495374          False                           NaN
# 498157          False                           NaN
# 500940          False                           NaN
# 503723          False                           NaN
# ...               ...                           ...
# 20862868        False                           NaN
# 20865494        False                           NaN
# 20868120        False                           NaN
# 20870746        False                           NaN
# 20873372        False                           NaN
# 20875998         True                           NaN
# 20878624        False                           NaN
# 20881250        False                           NaN
# 20883876        False                           NaN
# 20886502        False                           NaN
# 20889128        False                           NaN
# 20891754        False                           NaN
# 20894380        False                           NaN
# 20897006        False                           NaN
# 20899632        False                           NaN
# 20902258        False                           NaN
# 20904884        False                           NaN
# 20907510        False                           NaN
# 20910136        False                           NaN
# 20912762        False                           NaN
# 20915388        False                           NaN
# 20918014        False                           NaN
# 20920640        False                           NaN
# 20923266        False                           NaN
# 20925892        False                           NaN
# 20928518        False                           NaN
# 20931144        False                           NaN
# 20933770        False                           NaN
# 20936396        False                           NaN
# 20939022        False                           NaN
#
# [1350 rows x 13 columns]

# %% [markdown]
# ## We now have the promotions for the whole of 2013.

# %%
data_from_2013_v1['Date_x'].min()
# Out:
# Timestamp('2013-01-04 00:00:00')

# %%
data_from_2013_v1['Date_x'].max()
# Out:
# Timestamp('2013-07-26 00:00:00')

# %% [markdown]
# ## We now have a seperate table with all the `promotion` data for the whole of `2013` from `04/01/2013` to `26/07/2013`. The two main dataframes are now:
# - data_from_2013_v1: `train`, `store` and `feature` merged into one
# - final_df: `test` and `feature` merged, duplicates dropped and filtered for only `2013` data.

# %% [markdown]
# ## To do:
# - Fill in the NaN values with zeros for now.
# - Create a histogram of all variables compared with all other variables
# - Focus on analysing the correlations between variables
# - Check out time-series analysis and its capabilities.
#
# Check: https://towardsdatascience.com/an-end-to-end-project-on-time-series-analysis-and-forecasting-with-python-4835e6bf050b

# %% [markdown]
# ## Now we will fill in the NaN null values with zeros

# %%
data_from_2013_v2 = data_from_2013_v1.fillna(0)

# %% [markdown]
# ## Let us now try join the Weekly Sales column to our new table then we can normalise

# %% [markdown]
# ## Now we need to normalise the data as a few columns are varying in decimal places.

# %%
from sklearn import preprocessing

# %%
columns_to_normalise = ['Store', 'Temperature', 'Fuel_Price', 'Promotion1', 'Promotion2', 'Promotion3', 'Promotion4', 
                       'Promotion5', 'CPI', 'Unemployment', 'Weekly_Sales to be predicted']

# %%
X = data_from_2013_v2[columns_to_normalise].values
min_max_scaler = preprocessing.MinMaxScaler()
X_scaled = min_max_scaler.fit_transform(X)
data_from_2013_v2 = pd.DataFrame(X_scaled)

# %%
data_from_2013_v2.head()
# Out:
#     0         1         2         3         4         5         6         7   \
# 0
# 1346    0.088721    0.037093  0.000000      0.000000
# 1347    0.011399    0.050956  0.000000      0.000000
# 1348    0.005555    0.027155  0.000000      0.000000
# 1349    0.000167    0.044721  0.000000      0.000000
#
#       Weekly_Sales to be predicted       Date  IsHoliday
# 0                              0.0 2013-01-04      False
# 1                              0.0 2013-01-11      False
# 2                              0.0 2013-01-18      False
# 3                              0.0 2013-01-25      False
# 4                              0.0 2013-02-01      False
# 5                              0.0 2013-02-08       True
# 6                              0.0 2013-02-15      False
# 7                              0.0 2013-02-22      False
# 8                              0.0 2013-03-01      False
# 9                              0.0 2013-03-08      False
# 10                             0.0 2013-03-15      False
# 11                             0.0 2013-03-22      False
# 12                             0.0 2013-03-29      False
# 13                             0.0 2013-04-05      False
# 14                             0.0 2013-04-12      False
# 15                             0.0 2013-04-19      False
# 16                             0.0 2013-04-26      False
# 17                             0.0 2013-05-03      False
# 18                             0.0 2013-05-10      False
# 19                             0.0 2013-05-17      False
# 20                             0.0 2013-05-24      False
# 21                             0.0 2013-05-31      False
# 22                             0.0 2013-06-07      False
# 23                             0.0 2013-06-14      False
# 24                             0.0 2013-06-21      False
# 25                             0.0 2013-06-28      False
# 26                             0.0 2013-07-05      False
# 27                             0.0 2013-07-12      False
# 28                             0.0 2013-07-19      False
# 29                             0.0 2013-07-26      False
# ...                            ...        ...        ...
# 1320                           0.0 2013-01-04      False
# 1321                           0.0 2013-01-11      False
# 1322                           0.0 2013-01-18      False
# 1323                           0.0 2013-01-25      False
# 1324                           0.0 2013-02-01      False
# 1325                           0.0 2013-02-08       True
# 1326                           0.0 2013-02-15      False
# 1327                           0.0 2013-02-22      False
# 1328                           0.0 2013-03-01      False
# 1329                           0.0 2013-03-08      False
# 1330                           0.0 2013-03-15      False
# 1331                           0.0 2013-03-22      False
# 1332                           0.0 2013-03-29      False
# 1333                           0.0 2013-04-05      False
# 1334                           0.0 2013-04-12      False
# 1335                           0.0 2013-04-19      False
# 1336                           0.0 2013-04-26      False
# 1337                           0.0 2013-05-03      False
# 1338                           0.0 2013-05-10      False
# 1339                           0.0 2013-05-17      False
# 1340                           0.0 2013-05-24      False
# 1341                           0.0 2013-05-31      False
# 1342                           0.0 2013-06-07      False
# 1343                           0.0 2013-06-14      False
# 1344                           0.0 2013-06-21      False
# 1345                           0.0 2013-06-28      False
# 1346                           0.0 2013-07-05      False
# 1347                           0.0 2013-07-12      False
# 1348                           0.0 2013-07-19      False
# 1349                           0.0 2013-07-26      False
#
# [1350 rows x 13 columns]

# %% [markdown]
# ## Creating a histogram of all the variables to see correlations

# %%
import seaborn as sea

# %%
"""
We will now use pairplot from the Seaborn library which allows us to draw statistical plots based 
on Matplotlib. Once we visualise the data it would be easier to detect outliers.
"""

# This is the subset of columns I will be focusing on, these can be changed to include other columns as well.
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sea.set_palette(flatui)
sea.pairplot(data_from_2013_v2[columns_to_normalise], height = 3.0)
plt.tight_layout()
plt.show()
